# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# Data_to_Ignore_for_Now           Potentially_Interesting_Data
# Interesting_Data                 Save_For_Later
# Octavia Initial.ipynb            Smaller_Claim_Medical_Header.csv

# %%
utah_df
# Out:
#          Proxy_Provider_ID Provider_Primary_Taxonomy_Code
# 0                 51214169                     2085R0202X
# 1                 51133254                     363LF0000X
# 2                 52068371                     207P00000X
# 3                 50112665                     363A00000X
# 4                 54363088                     261QE0700X
# 5                 52793563                     207W00000X
# 6                 53584900                     2085N0904X
# 7                 53756579                     207R00000X
# 8                 53476714                     235Z00000X
# 9                 51453742                     111N00000X
# 10                51232804                     2085R0202X
# 11                54434569                     207YX0007X
# 12                50770543                     207RC0000X
# 13                54036945                     2084F0202X
# 14                50033266                     152W00000X
# ...
