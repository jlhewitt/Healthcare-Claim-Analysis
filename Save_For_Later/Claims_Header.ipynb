# %%
import pandas as pd
import numpy as np

# %%
utah_df = pd.read_csv('Smaller_Claim_Medical_Header.csv')

# %%
utah_df
# Out:
#         Claim_ID Claim_Type_Cd Claim_Type_Desc  Admit_Type_Cd  \
# 0      248134065             P    Professional              9
# 1      186070247             P    Professional              9
# 2      249716086             P    Professional              9
# 3      248618084             P    Professional              9
# 4      278512556             P    Professional              9
# 5      279908505             O      Outpatient              9
# 6      279949652             P    Professional              9
# 7      249303559             P    Professional              9
# 8      281084958             P    Professional              9
# 9      238230063             P    Professional              9
# 10     280740659             P    Professional              9
# 11     283235494             P    Professional              9
# 12     249554668             P    Professional              9
# 13     247844821             P    Professional              9
# ...

# %%
medical_line_df = pd.read_csv('Smaller_Claim_Medical_Line.csv')

# %%
medical_line_df
# Out:
#         Claim_ID  Claim_Line_No  Place_of_Service_Cd  Rev_Cd CPT4_ID  \
# 0      358985506             19                   11     NaN   D9951
# 1      358982958              3                   11     NaN   D0120
# 2      238253746              1                   11     NaN   99213
# 3      358996411              3                   11     NaN   96372
# 4      358985561              2                   11     NaN   17280
# 5      358984479              1                   99   450.0   00000
# 6      171447849              1                   11     NaN   99213
# 7      358987119             24                   99   444.0   00000
# 8      358996654             32                   99   551.0   00000
# 9      281568939              1                   23     NaN   99284
# 10     239303210              1                   11     NaN   D4910
# 11     248413959              1                   11     NaN   97110
# 12     358995481              9                   99   551.0   00000
# ...
